# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-network-device-hardening/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``Network Device Hardening``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# ###### Quick Links
# ***
#
# * [Network Device Hardening](#topnetworkDeviceHardening)&nbsp;&nbsp;|&nbsp;&nbsp;[Test](#topnetworkDeviceHardeningTest)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# <a id="topnetworkDeviceHardening"></a>
# ### [Network Device Hardening](#networkDeviceHardening)
#
# - [Changing Credentials and Using Strong Passwords](#networkDeviceHardening1ChangingCredentialsandUsingStrongPasswords) <br/><br/>
# - [Hardware Trust (Firmware Trust) and Updating Firmware](#networkDeviceHardening2HardwareTrustandUpdatingFirmware) <br/><br/>
# - [Patching and Updates](#networkDeviceHardening3PatchingandUpdates) <br/><br/>
# - [File Hashing](#networkDeviceHardening4FileHashing) <br/><br/>
# - [Disabling Unnecessary Services](#networkDeviceHardening5DisablingUnnecessaryServices) <br/><br/>
# - [Secure Protocols](#networkDeviceHardening6SecureProtocols) <br/><br/>
# - [Cryptography](#networkDeviceHardening7Cryptography) <br/><br/>
# - [Generating New Keys](#networkDeviceHardening8GeneratingNewKeys) <br/><br/>
# - [Disabling Unused Ports](#networkDeviceHardening9DisablingUnusedPorts)

# %% [markdown]
# ### [Practice: Hardening Network Devices](#practicenetworkDeviceHardening)
#
# * [1. Exercise: Implement Network Device Hardening](#exercisenetworkDeviceHardening)

# %% [markdown]
# <a id="topnetworkDeviceHardeningTest"></a>
# ### ⚡ [Test](#networkDeviceHardeningTest)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkDeviceHardening"></a>
# ***
# ### Network Device Hardening
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkDeviceHardening1ChangingCredentialsandUsingStrongPasswords"></a>
# ***
# ##### Changing Credentials and Using Strong Passwords
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``choose strong passwords``.
#
# Virtually every user of technology these days would be familiar with the implementation of a password but despite their prevalence, they have been proven to be one of the main security vulnerabilities and this is often due to the fact that people will use simple passwords - might use children's names, birthdates, pet's names, or even their own name or part of it as the password or maybe part of the password but in many cases, if the attacker knows the person fairly well, they might have a fairly good chance of guessing the password.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Second Factor or Multi-factor Authentication
# ***

# %% [markdown]
# Can improve upon password security by implementing what's known as second factor, or multi-factor authentication, which just adds in more components over and above the password itself, so it begins with:
#
# > something you know
#
# - that would include a password but it might also be a PIN or a pattern, or maybe even a gesture that you have to perform
#
# Then you can combine that maybe with:
#
# > something you have
#
# - a physical component such as a smart card or a fob
#
# If you want to keep going, you can add in:
#
# > something you are
#
# - a biometric feature such as a fingerprint or maybe a retina scan
#
# So again it's the combination of them that make everything more secure - I might be able to guess your password, but if I also need to swipe your fingerprint, well, that certainly makes it more difficult.
#
# This is nothing really new, particularly if you think about bank cards or credit cards - you have to have the card itself and you must also have the PIN, so you need both, the something you have and the something you know - the PIN by itself is useless without the card - the card by itself is useless without the PIN, so it implements stronger authentication.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Strong Password Creation
# ***

# %% [markdown]
# With respect to just the password itself, you can still increase the security by implementing strong passwords and this involves avoiding personal information, for example, nothing that relates to you or your family and you should also avoid easily recognizable numbers, such as your address or phone number - particularly relates to a PIN.
#
# A lot of PINs on bank cards are only four digits, so people will often use the same four digits at the end of their phone number for the PIN, so again, if you know the person's phone number, that would likely be the first thing you might try.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Avoid Read Words
# ***

# %% [markdown]
# Can also avoid using real words - this makes it challenging for password cracking tools to guess the password.
#
# This is the dictionary attack - these types of programs simply run through every word in the dictionary.
#
# Certain programs can also process combinations of words or letters or numbers - that will take them more time, but they might still be able to gain access eventually, so use a combination that includes upper and lowercase letters with the addition of numbers and special characters and that will make it significantly more difficult for a dictionary attack to succeed.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Longer Passwords
# ***

# %% [markdown]
# Can also use longer passwords.
#
# A password that is at least eight characters in length is considered to be strong, particularly if you compare that to a password that is only three or four characters in length and they are quite simply harder to crack because of the higher number of characters, there are more possibilities.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Implement Passphrases
# ***

# %% [markdown]
# Might also be able to implement passphrases.
#
# A lot of applications and or operating system environments will accept up to 128 or maybe even 256 characters in the password, so you can basically just use these characters from a string of text, maybe a line from a song or a quote, or anything along those lines but again, you want to be a little bit careful with that, because if people know you very well, they might hear you use that phrase a lot in day to day conversation, so again, it might be easy for someone to guess what it is but it still is harder to guess, at least to something like a dictionary attack.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Password Storage
# ***

# %% [markdown]
# With respect to password storage, ideally you want users to remember the password or perhaps more specifically stated, you don't want them writing it down and then just hiding it under the keyboard or quite literally posting it on their desk or their monitor but there is a little bit of a balance here that you might want to try to find, because if you do require your users to create very complex passwords, then they will almost never remember it and conversely, they will almost always write it down.
#
# If they can secure the written down copy in a locked drawer, for example, then that is more secure because that exceptionally difficult password is almost impossible to guess by someone else, and very secure against something like a dictionary attack, so again, you do get enhanced security by having that impossible to guess password, but you need the written down copy to be secured as well, so if it was an attacker trying to use a dictionary attack, well, you're very safe against those but you're not all that safe against someone on the inside who might have access to the drawer to get the written down copy - again, there's a little bit of a balance that you might have to strike there.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Password Management Tools
# ***

# %% [markdown]
# But there are password management tools, software and applications that store the username and password and these usually do so in encrypted format, so that users don't have to remember it - the application itself will remember it and a lot of people might be familiar with the fact that browsers actually remember usernames and passwords.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Password Changing
# ***

# %% [markdown]
# Another aspect to consider is changing the password, so you should instruct users to update passwords on a regular basis, or perhaps more commonly, implement policies that require them to do so.
#
# The idea here being that if they have the same password forever, sooner or later somebody will figure out what it is, so by changing it, you force them to start all over again.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Passwords for Different Accounts
# ***

# %% [markdown]
# You should also use different passwords for different accounts, in other words, if you use the same password for everything, then you are certainly a lot more exposed to losses if somebody does get your password because they'd be able to access everything that you are securing with that password.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Not Save Password in the Browser
# ***

# %% [markdown]
# Generally, do not save password information in the browser - that comes back to what I just mentioned about the password management applications - there are some known as vaults that are dedicated to this process, but browsers do it as well and that might be okay as long as you are in a private environment, such as your home or your office at work, where you are the only one who uses that computer but certainly, if it's a public place, such as an Internet cafe, a library, or a hotel lobby, you certainly should not save password information in the browser because somebody who might just be doing a little bit of shoulder surfing could come right in behind you and access that same site that you just accessed with your account information.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Password Implementation that meet your needs
# ***

# %% [markdown]
# It might take a little bit of thought, a little bit of balance but ultimately, it's up to you to try to find a password implementation that is secure enough to meet your needs while not being so difficult to remember that you write it down and stick it on your monitor and hence defeat the purpose of password security.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkDeviceHardening2HardwareTrustandUpdatingFirmware"></a>
# ***
# ###### Hardware Trust (Firmware Trust) and Updating Firmware
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``update firmware``.
#
# In this presentation, we'll cover hardware trust, or perhaps more specifically stated, firmware trust and say that because, these days, a lot of hardware will come with an embedded chip right in the device and that chip contains a certain amount of software, dedicated instructions for how that particular component performs its job and that software is known as firmware.
#
# Given that it is dedicated software for a specific device that performs a specific task, they are usually very reliable - don't have to do all the things that an operating system has to do, for example but at the end of the day, it is still software that has been programmed for this hardware, so the software itself is still vulnerable to a degree.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Trusted Platform Module (TPM)
# ***

# %% [markdown]
# The ``Trusted Platform Module``, or the ``TPM`` is an embedded chip that is usually found these days in laptops, desktops, and servers, even other devices such as set-top boxes, like a PVR, or your TV tuner, smartphones, or even tablets and it's a device that was defined in the ``National Institute of Standards and Technology`` - ``NIST`` - trusted computing requirements and the SP stands for special publication, and then those numbers just indicate which document:
#
#
# - SP 800-147
#
#
# - SP 800-155
#
#
# - SP 800-164
#
#
# The idea behind a TPM is that it stores cryptographic keys - these, of course, can be used for encryption purposes to protect information.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Trusted Platform Module (TPM) - Microsoft BitLocker
# ***

# %% [markdown]
# A specific application of this is Microsoft BitLocker key storage - designed to encrypt all of the data on a volume so that everything is protected, not just individual files.
#
# If you don't have a TPM, some older systems might not, you can still implement BitLocker by using a USB flash drive - it can store those keys on the flash drive, but that's not as secure because the keys are readily available, if you will, on the flash drive whereas with a TPM, they are embedded right into the system.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Trusted Platform Module (TPM) - Initializes creates a Storage Root Key (SRK)
# ***

# %% [markdown]
# The TPM itself, when it initializes, it creates what's known as a ``Storage Root Key`` (``SRK``) and then any given application such as BitLocker can use this root key to protect its own application-based keys.
#
# This is a fairly common approach when it comes to applications that use encryption keys.
#
# A lot of database service, for example will create a key that resides at the server level or the service level because any one database server can have any number of databases on that server, so there's this master server level key, if you will - then for each individual database that I want to protect, I can create different database level keys, so the same thing goes with this TPM root key.
#
# That is, in essence, the master key and then any other application that needs to protect information can use that root key to protect its own application-based key, so BitLocker is an example of an application-based key.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Trusted Platform Module (TPM) - Detect Boot Changes
# ***

# %% [markdown]
# The TPM can also detect boot changes, and as such it can mitigate boot-kit threats - master boot record rootkits and the [2011 Mebromi](https://www.webroot.com/blog/2011/09/13/mebromi-the-first-bios-rootkit-in-the-wild/) attack are examples of these boot-kit threats.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Rootkit
# ***

# %% [markdown]
# Boot-kit and rootkit, are fairly similar but for the most part, a rootkit is a virus that gets into the system that tries to hide in plain sight, if you will, by disguising itself as legitimate files.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Bootkits
# ***

# %% [markdown]
# Boot-kits usually extend the capability of rootkits so that they can survive reboots, so if you just try to get rid of something because it's active in memory by rebooting - a boot-kit basically gets itself into the boot record and survives these reboots.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### TPM - Change to the Boot Environment is Detected
# ***

# %% [markdown]
# With the TPM, any kind of change to the boot environment is detected as suspicious activity and the system will then reboot and it will require a recovery key password, which, in essence, resets the boot environment back to the way it was and the protection that was implemented is able to say, well, I know that this is what it did look like before the suspicious activity, so I can just discard whatever change occurred and set everything back to the way it was, so, again, that's the idea behind the TPM, it can prevent that tampering of the boot environment again you just configure something like a password to ensure that you are an authorized user and then, in essence, your boot environment is back to the way it was.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### BitLocker
# ***

# %% [markdown]
# With respect to BitLocker, this particular application was designed to provide entire disk volume encryption.
#
# - ``EFS``, the ``Encrypting File System`` is a feature of Windows and the ``NTFS`` file system but that is used for individual files and folders
#
# This is used for the entire volume, so fixed disks on your system can be protected at the disc level and basically, this is designed to protect data at rest, so that if someone steals your system, even if they attempt to gain access to the data on the drive by removing the drive and attaching it to their own system where they are a local administrator, they cannot remove the encryption.
#
# They would be able to remove the NTFS permissions in that manner but the encryption is still there and requires the storage root key of the TPM to be able to access the data, so by just removing the hard drive, they don't get anywhere and, of course, even if they leave it in the system, because they stole your whole laptop, they would still need the password or the PIN to boot the system because you can configure the TPM to require a PIN, so as long as they do not have that PIN, they cannot gain access to the data.
#
# It can also be implemented for removable media, so if you have an external USB hard drive or a flash drive, you can implement ``BitLocker To Go`` to protect the data on those drives as well and that's fairly common, of course, because they're very easily lost or stolen, so, again, the idea is to protect the entire contents of that disc or volume.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Firmware Updates
# ***

# %% [markdown]
# Firmware updates, of course, are very common - computers contain a lot of firmware - USB peripherals, graphic cards, web cams - malware can be injected into the firmware of computers, so you want to regularly check with the manufacturer for firmware updates, and some devices will often inform you - just pop up and tell you there is an update, but not always, so it's a good idea to keep on top of it and to make sure that everything is current and usually the updates are security related - they'll say, we found a security vulnerability, here's the fix for it, so please apply this.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - TPMs help to keep System more Secure
# ***

# %% [markdown]
# But ultimately, it's like anything, you just want to keep on top of it and ensure the standard activity that you do on a day-to-day basis does not invite these types of malware applications but, again, some of them are fairly tricky to detect and even to remove, so TPMs can certainly help you in keeping your system more secure.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkDeviceHardening3PatchingandUpdates"></a>
# ***
# ###### Patching and Updates
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``implement patches and updates``.
#
# Deals with the fact that, of course, manufacturers and vendors always want to improve upon their products and in many cases they will of course release new versions that are designed to entirely replace the older versions but there can be a fair amount of time in between, let's say, version X and version Y, so patches are usually small fixes that are implemented in between those two versions.
#
# Then, for lack of a better description, the newer version might be just a complete roll up of all of the earlier patches plus perhaps some new features, of course but the idea in most cases is that vulnerabilities are discovered over time and they can be related to security or stability, or really anything, compatibility perhaps, so patching fixes those problems in the short term, if you will, until the next version.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Monitor Patch Deployment
# ***

# %% [markdown]
# Typically do have to monitor the patch deployment that is going on in your environment because you want to be assured that everything is as up to date as possible.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Patch Compliance
# ***

# %% [markdown]
# Also want to keep an eye on patch compliance, in some cases you might have a particular configuration and the patch that you have implemented might actually throw that device or application or service out of compliance, so it's something that you do need to monitor, and in most cases you also just want to ensure that the patch is doing something desirable - they don't always fix every problem exactly the way you need them to.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Injecct Patches into OS Images
# ***

# %% [markdown]
# In many cases you can also inject patches into operating system images.
#
# A lot of environments deploy new computers by just pulling down an image from a server that includes an already configured operating system with respect to its drivers, its applications, and its updates but of course, updates are released all the time, so as these new updates come down, in a lot of cases, you can inject the patch into the image, so the next time you apply that image, it is already updated and of course all of these represent ongoing tasks - you always have to keep on top of the patches and the updates that are being released.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Patching Overview - Hardware
# ***

# %% [markdown]
# Can patch at multiple different levels beginning with hardware - there are BIOS updates - there are wireless router firmware updates and then firmware updates to printers, routers, switches, mobile devices, and even the Internet of Things often have firmware updates as well.
#
# Firmware again is specific software that is typically embedded within the hardware, but these are typically still considered to be hardware updates but firmware is the more appropriate term.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Patching Overview - Software
# ***

# %% [markdown]
# In terms of software, your operating system, particularly with respect to its security and its service pack level, that's typically a Windows feature but service packs in many cases represent a roll up of multiple patches.
#
# Then drivers, applications, and the apps on your mobile devices all need patches and updates as well, so again, we see patches at multiple levels within the software environment as well.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Patch Deadlines
# ***

# %% [markdown]
# In a lot of cases there are patch deadlines, whereby you need to have this particular patch installed by a certain time - up to administration in many cases - they might say yes, we want to implement this patch and even the fact that you implement it or not is really up to you as well but if you do decide that you want to implement it, it could take a while in large environments to get it deployed throughout the entire environment, so you effectively set this deadline and you just notify the user that a particular update has to be installed by the end of the day or something along those lines.
#
# Doing so can slow down the computer and the network just because everybody's trying to do the update before the deadline but it does ensure that all systems are up to date by that point in time.
#
# Also have to be mindful of the reboot behavior because a lot of patches and updates require the system to be rebooted, so you don't want to disrupt your regular daily activity by requiring users to reboot in the middle of the day when they are at their busiest for example - in a lot of cases you'll see patches will be applied during downtime, such as after 6 PM when everybody goes home.
#
# There can also be license agreement behavior as well, so the user has to agree, or at least someone sitting at the computer has to agree to install it, so some of them can be deployed somewhat automatically, some might be a little more manual, depends on the nature of the patch.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Windows Server Update Services (WSUS)
# ***

# %% [markdown]
# An example of one of the interfaces - this is what's known as ``WSUS``, or ``Windows Server Update Services`` and what you can do with this is, effectively, gather up updates for any given amount of time - can categorize them into critical updates, security updates, and you can also define different groups so that I can maybe test the updates before they are actually deployed.
#
# Then I can also just go through each of the updates and decide if it's something that I actually want to deploy because in many cases, it could be a configuration that conflicts with your own policy, or it might just be for an application feature that you don't use, so you don't need to install every single update all the time, it is up to you but you can see in the graphic here - ``Approved Updates`` - in essence, of course, means that yes, we are going to deploy these updates but again, they don't all have to be approved and even those that are don't all have to be installed at the same time, so you can release them in a phased approach, if you will - do a lab or a testing environment first - make sure everything remains stable, then you can deploy them to the rest of your environment.

# %% [markdown]
# > Interface ``Windows Server Update Services`` - ``WSUS``:
#
#
# - navigation pane with an ``Updated Services`` directory - contains ``SRV2012-2``, ``Computer``, ``Downstream Services``, ``Synchronization``, ``Reports``, ``Options``
#
#
# - ``SRV2012-2`` is expanded to show ``Updates``, which is expanded to show ``All Updates``, ``Critical Updates``, ``Security Updates``, ``WSUS updates``
#
#
# - ``Computer`` is expanded to show ``All Computers``, which is expanded to show ``Unassigned Computers``, ``Halifax_Computers``, ``Update_Testing``
#
#
# The display pane showing ``All Updates`` - is obscured by a pop-up window, ``Approved Updates`` - this contains a table with columns, ``Computer Group; Approval; Deadline``.
#
# There is one entry, ``All Computers``, with an ``Approval`` - ``Keep existing approvals``.
#
# This is is expanded to show, ``Unassigned Computers, Halifax_Computers, Update_Testing``, each with an ``Approval`` of ``Keep existing approvals``.
#
#
# - ``Update_Testing`` is selected and there is a dropdown menu with options: ``Approved for Install, Approved for Removal, Not Approved, Same as Parent, Keep Existing Approvals (inactive), Deadline (inactive), Apply to Children (inactive)``

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Good Practice to stay on top of Updates
# ***

# %% [markdown]
# In general, it is considered a good practice to stay on top of updates, and to ensure that you do analyze them and review them to make sure that you are applying the ones that are going to be beneficial and this will certainly help to keep your environment as healthy as possible.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkDeviceHardening4FileHashing"></a>
# ***
# ###### File Hashing
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``implement file hashing``.
#
# The concept of hashing, at a very simple level, it is taking a value, running it through some kind of mathematical algorithm or function to produce another value.
#
# It's similar to encryption, but it doesn't really have the same approach - if, for example, I have a document that I want to ensure that no one can read, then I might encrypt it, that renders the data unreadable to anyone who does not have the decryption key.
#
# Hashing is not so much concerned with rendering it unreadable but rather ensuring that the information does not change, so for a very simple example, imagine you have a document and you open it up and you type in the number two - then you say, I want to apply a hash algorithm to that file, and the function or the algorithm is to simply say, take whatever the value of the document was and add two to the value, so it should then read the value of two, add two to the value and come up with an answer of four - four represents the hash value.
#
# If then somebody opens the document without me knowing it and alters the data and changes it to three, then they close down the file and say, all right, I've compromised this file now, the hash will change because the hash said to simply take the existing value and add two to it, so now I get a hash value of five, and I know that this document has changed - again, that's a very basic example, but that is the essence of hashing - take some kind of information, run it through a function, produce a hash value, if that value changes, then the data has to have changed.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Algorithms - ``MD4``
# ***

# %% [markdown]
# MD4 was invented by Ron Rivest - that is the R of RSA encryption used in PKI, Public Key Infrastructure.
#
#
# - ``MD`` - stands for Message Digest
#
#
# - ``4`` - the version
#
#
# This algorithm produces a 128-bit hash value, which is 16 bytes.
#
# The security of MD4 itself has been compromised, in other words, an attacker can modify the contents of the original file and then compromise the hash, so that the hash still comes out to be the same even though the original data did change, so it's not recommended to be used any longer.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Algorithms - ``MD5``
# ***

# %% [markdown]
# MD5 was a newer version, still a Cryptographic hash function, and it still produced a 128-bit hash value, which is 16 bytes, so the hash value, the answer is represented by a 32 digit hexadecimal number and again, the common uses were for applications and maintaining the data integrity.
#
# Back to my example, obviously entering in the number two would be very easily detected if someone changed it to three but for very large documents, in particular, databases, a small change can be very difficult to detect but hashing can always detect it so we can maintain the data integrity by using hashing.
#
# MD5, of course, replaced the earlier MD4 function, but MD5 has since also been compromised, what's known as a ``Collision attack`` and or a ``Rainbow table`` can be used for ``Password cracking`` so that when you hash passwords - a Rainbow table, in essence, refers to all of the colors of the rainbow, it tries every possibility, so MD5 also no longer recommended for production use.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Algorithms - ``SHA``
# ***

# %% [markdown]
# SHA is the Secure Hash Algorithm and this is a family of cryptography hash functions and it was designed by the National Institute of Standards and Technology, as well as the National Security Agency, to effectively be the successor.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Algorithms - ``SHA-0``
# ***

# %% [markdown]
# SHA-0 of course was the first release and this was quite some time ago, so significant flaws were identified - produced 160-bit hash function, but it had a maximum message size of 2 to the power 64 minus 1 bits, and it was of course replaced by SHA-1.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Algorithms - ``SHA-1``
# ***

# %% [markdown]
# SHA-1 came along, and it still used 160-bit hash function - was designed by the NSA, the National Security Agency, and this is a ``Digital Signature Algorithm`` with a maximum message size, again of 2 to the power of 64 minus 1 but it was also identified as susceptible so it was no longer approved after 2010 for most cryptographic uses.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Algorithms - ``SHA-2``
# ***

# %% [markdown]
# SHA-2 consists of both 256 and 512-bit algorithms, which produce 32 or 64-bit words - a word is just a unit of measure for how many characters are produced by the hashing algorithm.
#
# There are some truncated versions as well, SHA-224, 384, 512 with 224 and 256, so these are just variations on how many bits are sent in to the algorithm and how long the resulting hash value is.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Algorithms - Keccak - ``SHA-3``
# ***

# %% [markdown]
# The newest version is SHA-3, formally known as ``Keccak``, and this was released by NIST on August 5th, 2015, so this is approved, of course, for current use.
#
# It uses what's known as a ``Sponge construction``, meaning that it effectively soaks up the data, if you will - put a sponge in water, it soaks up the water and when you squeeze it you ring out the water, but it's kind of in a different form if you will, so that's just a loose analogy of how the data is absorbed, and then how it comes out of the algorithm.
#
# With SHA-3, there is no limit on the size of the message, so it can basically be used against anything regardless of how large it is - now, the earlier ones were still quite large, you know, 2 to the power of 64 is enormous, but is still a limit, so with SHA-3, you can run anything through in terms of the size, and you will still get a hashed version of that data coming out the other side.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - About ensuring the Data has not Changed
# ***

# %% [markdown]
# So again, it's not really about making the data unreadable but rather just ensuring that the data has not changed and if it did, again you can revert to a back up and you can restore an unaffected copy.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkDeviceHardening5DisablingUnnecessaryServices"></a>
# ***
# ###### Disabling Unnecessary Services
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``disable unnecessary services``.
#
# Looking at a very simple implementation of security but despite its simplicity, in a lot of cases it's overlooked, and it's the process referred to as hardening.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Attack Surface
# ***

# %% [markdown]
# Before we look at that specifically, need to also understand the attack surface.
#
# The attack surface of a host or a device represents all the ways by which it can be attacked, so ideally, you should always be looking at ways of hardening, or reducing the attack surface.
#
# If you are an attacker, of course you are going to try and find every vulnerability - if you are the one being attacked, you want to try to mitigate those vulnerabilities as much as possible.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Hardening Categories
# ***

# %% [markdown]
# Categories of hardening include trying to identify the vulnerabilities in your:
#
# - Network attack surface
#
#
# - Software attack surface
#
#
# - Physical attack surface

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Hardening Process - Services
# ***

# %% [markdown]
# When it comes to the process of hardening, one of the first things that you should typically check on a server are its services and in essence, services represent the collective abilities of that server.
#
# If, for example, it's a mail server, then it provides you with email services, so anything that is unnecessary should be disabled on that server, because any service that is running has an associated open port that the client machines can connect to - common examples include Web servers, File servers, E-mail servers, Remote Desktop servers, these are the services that they supply.
#
# So if, for example, you have a mail server, it provides Simple Mail Transfer Protocol services over port 25 - if it's a web server, it provides HTTP services over port 80.
#
# Obviously those services are necessary for that particular server to perform that particular job but if you are a dedicated web server, then you should not also be running mail services and vice versa - if you are a dedicated mail server, you should not be running web services, so in essence, whichever services are not being used on that server should just be shut down, that way those ports are no longer open, and you reduce the attack surface.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Examine Servers and just Disable Unnecessary Services
# ***

# %% [markdown]
# In essence, you want to examine your servers and just disable the unnecessary services - many security incidents occur as a result of a security hole, such as an unnecessary service.
#
# Most computers have more services running than they require, and that's just a default configuration, any given server cannot assume that it is going to be used for a particular service.
#
# In most cases, a lot of services are enabled, so the more services running, the more opportunity for an attacker to get in through that port, so the more you close down, the less chance of an attacker being able to find their way in.
#
# As mentioned, it's a very simple process but it's often overlooked just because it is something that is fairly standard in terms of the configuration of most servers, those services are up and running, and we just install the software and then we configure them for the purpose we need them for and we just often forget that those other services are running in a lot of cases.
#
# It's just a matter of a little bit of vigilance but going through and locating those services that just aren't used and simply shutting them down so that they don't present those additional avenues of attack to someone who is trying to compromise those servers.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkDeviceHardening6SecureProtocols"></a>
# ***
# ###### Secure Protocols
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``implement secure protocols``.
#
# Recapping many of the secure protocols that have been discussed to just review their purpose, and/or their implementation but when it comes to all secure protocols, they are, of course, designed to ensure security and the integrity of your data - the security, of course, refers to whether or not people can access it at all - the integrity typically refers to whether or not the data has been tampered with or changed.
#
# Ultimately, we are always trying to protect the network data from unauthorized users, applications, services, or devices and typically, the way by which we secure that information is to implement cryptography or encryption, so that if somebody does intercept the data, they would be unable to actually read it.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Secure File Transfere Protocol (SFTP)
# ***

# %% [markdown]
# With the SFTP protocol, the Secure File Transfer Protocol, which runs over the secure shell protocol - supports security and authentication of secure shell and protects against ``Password sniffing`` and ``Man-in-the-middle attacks``, and is effectively the replacement for legacy FTP, and/or FTP/S protocols.
#
# It offers the same functionality but with Increased reliability and Easier configuration, so again, FTP by itself just transfers files in plain text, so anyone who might intercept would have full access to those files - clearly, if we wanted to be secured, we then implement SFTP and we ensure, again, not just the security, but the integrity of the data by ensuring that only authorized people are able to gain access and that the data has not changed in an unauthorized manner.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Simple Network Management Protocol (SNMPv3)
# ***

# %% [markdown]
# SNMPv3 is essentially the latest and most current implementation of the Simple Network Management Protocol.
#
# Initially, version one was inherently insecure with passwords, or what's known as community strings, passed in plaintext, so again, you needed a password, but anyone who was capturing data on the network could clearly read what those passwords are.
#
# Version 2 offered some improvements, but still had issues that were identified, so version 3 was designed explicitly to tackle security issues and is the current implementation that is accepted.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Secure Hypertext Transfer Protocol (HTTPS)
# ***

# %% [markdown]
# Secure Hypertext Transfer Protocol or HTTPS is of course an extension to HTTP, which is used to securely exchange files on the World Wide Web.
#
# This uses a combination of Encryption and Digital certificates, and, of course, is common in online Banking or Online shopping to ensure that these transactions that are occurring over the very public Internet can in fact be done privately.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Secure Sockets Layer (SSL)
# ***

# %% [markdown]
# SSL, or Secure Sockets Layer, is the networking protocol used to secure the connection over the network, most commonly the Internet.
#
# It's used to establish that tunnel, if you will, through the Internet by which you can then exchange secure information - uses a combination of:
#
# - Public key encryption
#
#
# - Symmetric key encryption
#
# Recall, there is an exchange of a public and a private key, which are different keys.
#
# Once that public key has been issued, this is used by the sender to protect a symmetric key, a third key, which is then sent back to the recipient so that both entities know which encryption key to use.
#
# The public key cannot be used to decrypt information, only the private key can and the private key is held only by the secure recipient, so anyone who is attacking can get a public key, but a public key cannot be used to reveal the contents - in other words, the symmetric key, so it secures the communication.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Transport Layer Security (TLS)
# ***

# %% [markdown]
# In fact, SSL has been deprecated as of 2015, but replaced by TLS, or Transport Layer Security, so this is just a newer implementation.
#
# A popular security protocol for web browsers and designed as the replacement for SSL but it is backward compatible with SSL version 3.0, so that if your browser, for example, does not support TLS, as long as it supports SSL 3 it can still be used for communication.
#
# In terms of its purpose, it's still really the same, to exchange data over a network in a secure fashion, so file transfers, VPN connections, instant messaging, VoIP, really, it doesn't matter what it is, but it is used to establish that secure connection so that we can begin transferring data in a secure fashion.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Secure Internet Protocol (IPsec)
# ***

# %% [markdown]
# IPsec - ``secure IP`` - uses a combination of three main protocols to create a security framework:
#
# > Internet Key Exchange (``IKE``): Provides a framework for a negotiation of security parameters and the establishment of authenticated keys.
#
# > Encapsulating Security Payload (``ESP``): Provides a framework for actually encrypting the data, authenticating the users or the devices and ensuring the integrity of the data itself.
#
# > Authentication Header (``AH``): Provides a framework for authenticating and integrity of the data - not just the user or the device, but the actual data.
#
# Implemented as an IETF, or Internet Engineering Task Force standard that employs cryptographic mechanisms on the network layer, in essence, meaning that every packet that crosses the connection can be authenticated, so every IP packet is secured.
#
# This provides for verification of data integrity for each packet and the confidentiality of the packet payload, so IPsec is more so used within an internal LAN environment but can in fact still be used over the Internet, for example, you can create VPN connections that are secured by IPsec but it's a little more proprietary for certain operating systems and/or applications.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Any Secure Protocol recommended when needing to Secure Data
# ***

# %% [markdown]
# Ultimately, the use of any secure protocol is, of course, recommended when you need to secure data.
#
# It just depends on the application, depends on the operating system and really just what it is that you are transferring - how you want to accomplish that, will dictate the choice of the secure protocol.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkDeviceHardening7Cryptography"></a>
# ***
# ###### Cryptography
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``implement cryptography``.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Availability and Confidentiality and Integrity
# ***

# %% [markdown]
# Core principles of information security:
#
#
# - Availability
#
#
# - Confidentiality
#
#
# - Integrity
#
#
# Cryptography in and of itself might not have a whole lot to do with availability - that is simply ensuring that the data that I need is available to me but if I need that information to be confidential, then encryption can certainly handle that and if I want to ensure that the data is intact, in other words it has not been tampered with, then something like a digital signature or a hashing algorithm can ensure that integrity.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Authentication - Non-repudiation - Access Control
# ***

# %% [markdown]
# Cryptography can also provide authentication, validating which entity you might be dealing with.
#
# Non-repudiation, which insures that a person in essence cannot disavow themselves of some type of action saying, that wasn't me, or I didn't do that and it can also provide access control ensuring that only the appropriate entities are able to gain access to this information.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Earlier Implementation
# ***

# %% [markdown]
# These days, our implementations of cryptography have certainly improved over some of the earlier implementations and really it comes down to the strength of the encryption and how hard it is to crack.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Data Encryption Standard (DES) - 3DES
# ***

# %% [markdown]
# For quite some time now, there have been various algorithms in use to provide the encryption, including the Data Encryption Standard, or DES - that's fairly old, but has been improved upon with what's known as triple DES - uses three separate keys as opposed to just one.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Diffie Hellman
# ***

# %% [markdown]
# Diffie Hellman, although this is only used to perform key agreement, it can't generate or verify any kind of digital signature.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### RSA (Rivest, Shamir, and Adleman) - Public Key Infrastructure (PKI)
# ***

# %% [markdown]
# If you have ever used any kind of Internet financial transaction service, such as online banking or a shopping site, then in fact you have all ready used RSA, Rivest, Shamir, and Adleman.
#
# These are the three mathematicians that came up with this algorithm and it is the basis of what we call ``PKI``, ``Public Key Infrastructure``, and online banking and credit card transactions use exactly that mechanism.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Pretty Good Privacy (PGP)
# ***

# %% [markdown]
# PGP, or Pretty Good Privacy, is typically used for email security.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Advanced Encryption Standard (AES)
# ***

# %% [markdown]
# The Advanced Encryption Standard or AES is probably the newest one of these algorithms, and generally regarded as acceptable in strength by even some of the highest standards organizations, such as military and governments and you might actually see AES if you were configuring something like a VPN or perhaps even a wireless router - might see that as an option for the encryption.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Cryptography Terminology
# ***

# %% [markdown]
# When it comes to terminology, you might hear a fair number of these used somewhat interchangeably but for official definitions:
#
# > Cryptanalysis is quite simply the study of Cryptosystems.
#
# > Cryptography itself is the use of tools and mechanisms designed to protect information, in essence, engineering solutions to come up with means to encrypt data.
#
# > Cryptology is how the mathematics apply to Cryptographic algorithms, because it is all based on math.
#
# > Cryptosystem is the collective overall implementation of all components.
#
# > Algorithm, in and of itself, is just a mathematical function - can send a number or a value into the algorithm and it will produce something coming out on the other side.
#
# > Cipher is quite simply an example of an algorithm, but one that is specifically designed for encryption purposes.
#
# > Plaintext or cleartext, is essentially the data before it is protected, so the plain message that you are wanting to send, for example.
#
# > Ciphertext or cryptogram refers to the result of encrypting the cleartext, so it's what you see on the other side of the algorithm - the function produces the Ciphertext.
#
# > Encipher or Encrypt, or Encode means to apply the encryption method and this is often achieved with whats known as a public key, and that refers back to the PKI - that Public Key Infrastructure.
#
# > Decipher or Decrypt, or Decode, is often done with a private key, and that removes the encryption, so very quick example, if I want to send you a message privately using encryption, you would send me your public key - anyone can obtain the public key, hence its name but I use that to encrypt the information - it cannot be used to decrypt it, so although anyone can get a public key, it is only used to encrypt - I send you the message that was encrypted with your public key, then you use your own private key to decrypt it and you are the only entity that holds your private key, so again, even though multiple people can get a public, they cannot use that public to decrypt the data, only your private can do that.
#
# > Work factor refers to the amount of effort and or the resources required to break an encryption system and obviously, you want that to be as high as possible - want a very demanding workload to be required to break your encryption system.
#
# > Key is the value or the parameter applied to the seed material, in essence, the algorithm.
#
# > Key clustering refers to separate keys that generate the same encrypted data from the same plaintext - generally, this is something that you don't want - if you are trying to achieve the highest levels of security, you want keys to produce different values from the same plaintext, so this again is simply something that you would try to avoid, keys that generate the same encrypted data from the same plain text.
#
# > Key space is the total number of available keys within a Cryptosystem, and the more keys you have, the stronger the system.
#
# > Initialization Vector ``IV`` is a random value that's used when encrypting data, so that if you do happen to encrypt the exact same plaintext, the results will vary - in other words, this is kind of the opposite of key clustering - you don't want the same value to produce the same encrypted data - want it to produce different data.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Ciphers used in Cryptography
# ***

# %% [markdown]
# Some of ciphers used in cryptography - very common ciphers include the Substitution and the Transposition.
#
# > ``Substitution`` is quite simply, substitute this character, or this set of characters, for that character, so you scramble it.
#
# > ``Transposition`` involves moving the position of the characters.
#
# > ``Running Key Cipher`` is actually drawn from a known phrase, or a book, or something like that, so you quite simply extract a phrase from a book or from any known piece of text, as long as it's known by both ends, that becomes your key, so you find a passage or a phrase that has the same number of characters as what you are wanting to encrypt and then you run it through a matrix, whereby you have the alphabet from A to Z across the top in one row but then the alphabet again on the second row, but starting with the letter b - then starting with the letter c, and the letter d, and so on and so on and that creates a matrix, and you use whichever value you want to encrypt in comparison with the value from the known passage and you just run through the matrix and find the letter, so the algorithm itself is not particularly complicated, but you need to know which phrase, or which passage was used in the first place.
#
# > ``Concealment Cipher`` is a message within a message, so something like read every third word, for example.
#
# > ``Block Cipher`` means that it simply works on blocks of text all at once as compared to a ``Stream Cipher`` which works bit by bit.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Protect the Data
# ***

# %% [markdown]
# Ultimately, it depends on the application and the type of information you are wanting to protect, and how you want to protect that in terms of which cipher will be used but one way or another, they all protect the data so that if it is intercepted, it cannot be translated back into plaintext.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkDeviceHardening8GeneratingNewKeys"></a>
# ***
# ###### Generating New Keys
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``generate new keys``.
#
# Looking at some different types of encryption keys, some of their properties, and some of their management tasks, including generating new keys when necessary.
#
# Some of the properties, with respect to any kind of encryption key, refer to whether or not it is the same key used for both encryption and decryption.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Same Key used for both Encryption and Decryption - Symmetric Algorithm
# ***

# %% [markdown]
# Symmetric Key is an algorithm whereby the encryption key is also the decryption key, so both parties need to know this but of course it has to be kept secret.
#
# If you, for example, have to transmit from one point to another, what the key is then that process itself is vulnerable because if that were to be intercepted, then that person now knows the encryption key and the decryption key and whatever data you would send using that key could easily be compromised.
#
# An ``Initialization Vector`` (``IV``) should be change for each session - every time it is transmitted, it should have a different initialization vector, so that if it does become compromised, at least for the next session, it is a different initialization vector but at the end of the day, it is still the same key for encrypting the decrypting.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Two Keys used for both Encryption and Decryption - Asymmetric Algorithm
# ***

# %% [markdown]
# In contrast the asymmetric algorithm involves two keys:
#
#
# 1. public key
#
#
# 2. private key
#
#
# In this scenario only the public key is used for encryption - the private key is the only thing that can then be used to decrypt that which was encrypted with the public, so, as its name suggests, the public key can be made available to anyone but only the intended recipient holds the private key, so again, if I'm needing to send you a message, the first thing I do is obtain your public key - anyone can get that, but even if the message is intercepted, the only thing they have, in terms of the overall encryption process is the same key that I use to encrypt the information.
#
# The public key, again, cannot be used to decrypt the information - it doesn't have enough information in it for lack of a better word - have to have the private key to decrypt the data, and again, the intended recipient is the only one that holds the private, so this makes it a little more secure in terms of exchanging information even if the public key is obtained by anyone else, it's of no use to them.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Encryption Key Life Cycle
# ***

# %% [markdown]
# There is an encryption key life cycle, in terms of when you are implementing any kind of encryption mechanism, so, in essence, it means that keys begin, have a lifespan, and expire.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The generation process is also known as the ``Pre-Activation``, when you quite simply say, let's generate the keys.
#
# They can become active right away at that point, but they don't have to, you can hold onto them for a little while before they actually get implemented - that then would be ``Activation`` - let's say a week later you decide to start distributing these keys.
#
# Then they're valid for a certain amount of time but typically, you don't want to leave them valid for too long, because the longer they are in use, the more chance that they will ultimately become compromised - can enter this period of ``Escrow``, if you will, where for the most part, it just means the key is backed up because it might still have been used to protect data that in and of itself has also been archived, so we'll back up the key and key it - that's ``Post-Activation``.
#
# Then ultimately once that key is no longer needed, and you've applied new keys you can ``Destroy`` the old one, so again, they quite simply have an ``Expiration`` date.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Key Creation - Key Management Servers
# ***

# %% [markdown]
# When it comes to key creation, key management servers are used to create and store the encryption keys and the key manager itself creates the encryption keys by using a cryptographically secure random bit generator - they keys are then stored in a key storage database which includes all of the attributes, or the properties, of the key.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Key Attributes or Properties
# ***

# %% [markdown]
# Those attributes include the name, the activation date, the size, how large the key is, and the larger it is, the stronger it is, the instances of those keys, in other words, which ones are being used right now in which circumstances, the rollover:
#
# > Which is when does this one become deactivated and a new one becomes activated?
#
# Mirroring as if there is another copy stored on another database somewhere as a fault tolerance mechanism and of course, key access is who is able to access the key for administrative purposes.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Key Created needs Activation
# ***

# %% [markdown]
# Once you create a key, of course, it does have to be activated at some point but by default, it's active upon its creation but you can say no, I don't want to distribute these keys yet, so you can activate later if you want to, and that in and of itself can be an automatic process or done manually and again, that's up to you how you want to implement that.
#
# But the instances then of those keys are tracked by the encryption key manager so it knows these keys are in use on these systems.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Specify whether Keys: i. can be deleted; ii mirrored to a failover unit; iii. accessed by certain users
# ***

# %% [markdown]
# Finally then, you also have to specify whether keys can be deleted and/or whether not they are mirrored to a fail over unit and then, as mentioned, whether or not they can be accessed.
#
# Someone needs to access them but you, of course, have to specify which users or groups are able to do so and administration, of course, should always be allowed to manage these attributes at any time and this, of course, includes the generation of new keys - once we decide that these old keys should be archived and/or destroyed, then we start to process all over again and we generate new keys - now we have those keys protecting our data and everything starts over.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Shorter Lifespan more Secure
# ***

# %% [markdown]
# In terms of how long that lifespan that is entirely up to you but the shorter the lifespan, typically the more secure the information will be because you're changing the keys all the time but this has an associated increase in administrative overhead - you have more to do, more to look after, so you tend to want to try to find the balance between ensuring that your data is protected, but you're not constantly managing keys all the time and that in and of itself can lead to errors as well. Too much administration and/or too many administrators can cause problems.
#
# So, again it's all about finding the balance but managing keys ultimately deals with the fact that they do have this lifespan, they should be cycled in and out, they should be retired and new keys should be generated when deemed necessary.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkDeviceHardening9DisablingUnusedPorts"></a>
# ***
# ###### Disabling Unused Ports
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``disable unused ports such as IP ports and device ports``.
#
# Earlier, when we talked about hardening a server by disabling services, mentioned how there were ports that are always associated with each service but there are also other instances of ports that need to be considered when hardening your environment because any instance of any kind of unused port that is left open can present a security vulnerability, so, in this particular instance, we're referring more so to network-based ports or the implementation of a firewall.
#
# Ports can be blocked for the entire network using a firewall - if you are talking about protecting the entire network, then it does need to be a network firewall, this is not to be confused with a host-based firewall, such as the Windows firewall, that is only running on that specific system - now that's fine - not suggesting you should not use the Windows firewall to any degree, just that if you are looking to protect all of the systems within a network environment, you need that network firewall which is usually placed between the internal organization and the connection to the Internet.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Windows Firewall
# ***

# %% [markdown]
# The Windows firewall, of course, is used to manage the way that your computer communicates on the Internet with both inbound rules and outbound rules, in terms of what will be accepted and what will be replied to and there are also connection security rules, which simply secure the connection itself and not any specific port.
#
# Then, of course, you can also monitor to see which ports are open, which ones are closed but when it comes to the Windows firewall, this is only for that particular system. Now, as mentioned, that's fine, but it will not protect the entire network but you certainly can block or allow incoming communication, such as online games, so this is fairly common in a home environment where you might not have, of course, a very robust network firewall implementation.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Physical Device Ports
# ***

# %% [markdown]
# There are other ports that can also be disabled and at this level, we are more so referring to physical ports, the actual place where you insert the cable into something like a router or a switch, so you can disable those physical ports to prevent users from accessing the network.
#
# For example, just prevent someone from connecting a laptop to any open RJ-45 jack on the premises and, again, this is fairly common, people will just try to enter the organization, maybe posing as someone legitimate and then just connect their laptop to the first data port they encounter and begin their intrusion - you can ensure that they are unable to connect by disabling the physical port on the router or the switch on the other side of that data port, so that, of course, they just are not able to connect at all.
#
# There are several different types of physical device ports - many routers offer the capability to manage the physical ports on a device, so it's a good practice to disable these ports to prevent a rogue computer from plugging directly into the router device which, again, would prevent network access, so now we aren't talking about plugging into a data port in the wall, but maybe they have gained physical access to the router itself, so again, if you disable the port, it's not going to allow them to connect.
#
# Just reviewing which ports are open or available or in use, should always be part of the IT policy and, perhaps more to the point, which ones are not in use should be included as well.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Virtual Device Ports - TCP - UDP
# ***

# %% [markdown]
# There are also virtual device ports used in TCP and UDP connections, and these identify the unique end-to-end connection of an application but a single physical connector can also accommodate multiple connections to multiple applications or services and these are referred to as the virtual ports but, with respect to any kind of connection over TCP and/or UDP, there is always a port number associated with that application or service.
#
# Each side of the connection has its own port number that does not change with respect to establishing and maintaining that connection - now, it should be mentioned that port numbers for specific applications can be changed, in other words, the SMTP protocol, for example, email, always uses port 25 by default but you can change that if you want and the reason being is that virtually everyone in the IT administrative world knows that SMTP uses port 25 therefore, I know to launch my attacks against that port, so you can, in fact, change them, but you have to make sure that every system participating in the communication changes to the other port.
#
# That gets you a little bit more security, but not a lot, because port sniffers can always detect which ports are open and by capturing the traffic, an intruder can, you know, usually figure out that, they are handling their SMTP services over a different port but it's still another layer - it's better than nothing but in standard, default communications, the port numbers are already assigned and the applications use those ports exclusively, and they don't change.
#
# If you want to change it, you have to do so manually and you have to ensure that every system is configured to use that new port, so that's why they typically say they don't change.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Identify every Instance of Every Port
# ***

# %% [markdown]
# At the end of the day, the idea is to identify every instance of every port and every type of port that is not being used, and to quite simply disable it - by doing so, you harden the overall environment by reducing the attack surface.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="practicenetworkDeviceHardening"></a>
# ***
# ### Practice: Hardening Network Devices
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``implement network device hardening``
#
# i. Describe the characteristics of a strong password.
#
#
# ii. Describe file hashing.
#
#
# iii. Describe service hardening
#
#
# iv. Finally describe device hardening.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="exercisenetworkDeviceHardening"></a>
# ***
# ###### 1. Exercise: Implement Network Device Hardening
# ***

# %% [markdown]
# i. Describe the characteristics of a strong password.
#
# To be considered strong, and sometimes you'll hear the term complex, it generally requires the password to be at least eight characters in length, then to implement a mix of case, both upper and lowercase letters, then to also mix the use of letters, numbers, and/or symbols and typically, if you meet those three, then it would be accepted as a complex password by most network password policies but you can certainly go beyond this.
#
# A lot of passwords will support up to 128 characters, so in some cases you might even implement a pass phrase of some kind, but that is certainly your call but the general rule of thumb is, of course, that shorter passwords that don't mix the case and don't mix the letters are certainly going to be easier to guess, or for some sort of password-cracking program to be able to ascertain.

# %% [markdown]
# ii. Then we asked to describe file hashing.
#
# This is the process of applying a mathematical algorithm to a file to produce a value that can be used to determine if the file contents have changed, so again, you start with the original value, which is the contents of the file itself and then you use that information to run it through some kind of a function that produces an answer, for lack of a better word, so then if the original data changes, and you run it through the same function, you will get a different hash value - a different answer will come out if you start with a different file, therefore, this indicates that the file has been changed, so if you know it should not have been changed, then in essence, somebody has tampered with that file.

# %% [markdown]
# iii. Then we asked to describe service hardening, and this is simply the process of disabling services on a server that are not in use, so if you go to just about any server and examine the services that are running, in many cases, there are more running than what is necessary.
#
# If that server is being dedicated to a specific task, for example, then the tasks that it does not perform should simply be disabled because each running service has a port associated with it and if that service is running, then the port is open, and it presents an avenue of attack, so quite simply, shutting down that service disables the port.

# %% [markdown]
# iv. Then describe device hardening and this is the same approach, but more so referring to disabling physical ports that are not in use, such as on routers or switches or blocking ports on a firewall.
#
# This protects the entire network, in many cases, by simply not allowing any kind of communication over that specific port.
#
# In both cases, hardening just refers to shutting down that which is not in use or undesirable and the more you reduce those open ports, the more you reduce the attack surface of your overall environment.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkDeviceHardeningTest"></a>
# ***
# ### ⚡ Test
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
